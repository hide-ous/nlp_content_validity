# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../../data/external/matthews_et_al/relations.csv')

# %%
df.head()
# Out:
#                                focal_scale  orbiting_scale_1  \
# 0  Abusive supervision - active-aggressive               NaN
# 1                     Affective commitment               NaN
# 2                 Authoritarian leadership               NaN
# 3                         Autonomy climate               NaN
# 4                              Bureaucracy               NaN
#
#    orbiting_scale_2  items  sme_definitional_adequacy_mean  \
# 0               NaN      1                            4.19
# 1               NaN      1                            4.41
# 2               NaN      1                            4.05
# 3               NaN      1                            4.25
# 4               NaN      1                            3.92
#
#    sme_definitional_adequacy_std
# 0                           0.75
# 1                           0.87
# 2                           0.90
# 3                           0.72
# 4                           1.02

# %%
sns.displot(df['sme_definitional_adequacy_mean'], kde=True, rug=True)
